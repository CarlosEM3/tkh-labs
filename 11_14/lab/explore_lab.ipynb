# %% [markdown]
# ## Data Exploration Lab I
#
# For this lab, you will begin work on your 4th TLAB. The dataset for this lab is in the `../../data/shopping.csv` file.
#
# The goals for this process include:
#
# * dropping rows with missing data
# * dropping columns with overwhelmingly missing data
#
# After you've completed this process, answer the questions underneath `Data Cleaning Lab II` in your own words.

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
# TODO: load `../../data/shopping.csv` as a pandas dataframe

df = pd.read_csv("../data/shopping.csv")

# %%
# TODO: print out the first 5 rows for display

df.head()
# Out:
#    Customer ID   Age  Gender Item Purchased  Purchase Amount (USD)  Location  \
# 0         3475   NaN    Male         Jacket              30.904467     Maine
# 1         3698  21.0  Female       Backpack              31.588259       NaN
# 2         2756  31.0    Male       Leggings              24.231704    Nevada
# 3         3340   NaN    Male        Pajamas              33.918834  Nebraska
# 4         3391  38.0    Male     Sunglasses              36.545487    Oregon
#
#   Size         Color  Season  Review Rating Shipping Type Promo Code Used  \
# 0    M  Burnt orange    Fall            4.0      Standard              No
# 1    L     Turquoise  Winter            2.0       Express              No
# 2    M   Terra cotta  Winter            4.0      Standard              No
# 3    M         Black  Winter            NaN      Standard              No
# 4    S     Aubergine  Summer            NaN      Standard              No
#
#    Previous Purchases Payment Method Frequency of Purchases
# 0                   0    Credit Card                    NaN
# 1                   1    Credit Card                Monthly
# 2                   0    Credit Card                    NaN
# 3                   2    Credit Card              Bi-Weekly
# 4                   0    Credit Card                    NaN

# %%
# TODO: Print out summary statistics for all numeric columns

df.describe()
# Out:
#        Customer ID          Age  Purchase Amount (USD)  Review Rating  \
# count  3900.000000  3510.000000            3900.000000    1431.000000
# mean   1950.500000    34.256695              38.708329       3.904962
# std    1125.977353    10.616340              11.504923       1.105952
# min       1.000000    18.000000              11.392520       1.000000
# 25%     975.750000    26.000000              29.332617       4.000000
# 50%    1950.500000    33.000000              36.953004       4.000000
# 75%    2925.250000    41.000000              48.739596       5.000000
# max    3900.000000    75.000000              69.567481       5.000000
#
#        Previous Purchases
# count         3900.000000
# mean             5.841538
# std              5.843695
# min              0.000000
# 25%              1.000000
# 50%              4.000000
# 75%              9.000000
# max             20.000000

# %% [markdown]
# ## Univariate Analysis
#
# Let's generate visualizatons for each numeric variable to get an idea of the outliers & distributions present in our dataset.
#
# In addition, let's also visualize the frequency-count of qualitative variables to get an understanding of the composition of our dataset.

# %%
# TODO: count the frequency of unique values in the "Size" column, save this value into a new dataframe named "size_counts"
# Documentation: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.value_counts.html

size_counts = df["Size"].value_counts()
size_counts
# Out:
# Size
# M     1755
# L     1053
# S      663
# XL     429
# Name: count, dtype: int64

# %%
# TODO: plot a matplotlib barplot for the size_counts dataframe
# Documentation: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.bar.html

size_counts.plot.bar()
# Out:
# <Axes: xlabel='Size'>

# %%
# TODO: count the frequency of unique values in the "Color" column, save this value into a new dataframe named "color_counts"

color_counts = df["Color"].value_counts()
color_counts
# Out:
# Color
# Black                   275
# Brick red               264
# Aubergine               263
# Burnt orange            262
# Terra cotta             259
# Ruby Red                258
# Brown                   247
# Mauve                   240
# Muted mustard yellow    238
# Baby blue               223
# Lavender                215
# Lemon yellow            203
# Pale peach              200
# White                   194
# Fuchsia                 188
# Periwinkle              186
# Turquoise               185
# Name: count, dtype: int64

# %%
# TODO: plot a  horizontal barplot for the color_counts dataframe
# Documentation: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.barh.html

color_counts.plot.barh()
# Out:
# <Axes: ylabel='Color'>

# %%
# TODO: count the frequency of unique values in the "Payment Method" column, save this value into a new dataframe named "pay_counts"

pay_counts = df["Payment Method"].value_counts()
pay_counts
# Out:
# Payment Method
# Credit Card      1400
# Debit Card       1300
# PayPal            600
# Venmo             579
# Bank Transfer      11
# Cash               10
# Name: count, dtype: int64

# %%
# TODO: plot a matplotlib barplot for the pay_counts dataframe

pay_counts.plot.bar()
# Out:
# <Axes: xlabel='Payment Method'>

# %%
# TODO: count the frequency of unique values in the "Location" column, save this value into a new dataframe named "loc_counts"

loc_counts = df.value_counts("Location")
loc_counts
# Out:
# Location
# California        91
# Alabama           81
# Delaware          81
# Nebraska          80
# Montana           80
# Illinois          79
# Minnesota         79
# Idaho             79
# West Virginia     78
# Nevada            77
# New York          77
# Maryland          77
# Louisiana         77
# Vermont           76
# Mississippi       75
# Kentucky          75
# North Dakota      74
# Texas             74
# South Carolina    72
# New Mexico        72
# North Carolina    72
# Indiana           71
# Virginia          71
# Georgia           71
# Maine             71
# Arkansas          70
# Wisconsin         69
# Missouri          68
# Massachusetts     68
# Ohio              68
# Oregon            67
# Tennessee         67
# New Hampshire     66
# Connecticut       66
# Pennsylvania      66
# Oklahoma          66
# Utah              66
# Colorado          65
# Alaska            65
# Michigan          65
# Iowa              65
# Washington        63
# Wyoming           62
# South Dakota      61
# Florida           61
# New Jersey        60
# Arizona           60
# Kansas            57
# Rhode Island      56
# Hawaii            53
# Name: count, dtype: int64

# %%
# TODO: plot a horizontal barplot for the loc_counts dataframe
# Documentation: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.barh.html
# Hint: resize the figure using "plt.figure(figsize=(10,10))" to "unsquish" your visualization

plt.figure(figsize=(10,10)) #this goes first bc its the size we want the graph
loc_counts.plot.barh()#this is the graph
# Out:
# <Axes: ylabel='Location'>

# %% [markdown]
# ## Bivariate Analysis
#
# Let's generate visualizatons for relationships between multiple numeric variables to get an idea of patterns and clusters that might be present in our dataset.

# %%
# TODO: Create a boxplot that reveals the range of "Purchase Amount (USD)" for each "Review Rating" 
# Documentation: https://seaborn.pydata.org/generated/seaborn.boxplot.html

sns.boxplot(data = df, x ="Review Rating", y = "Purchase Amount (USD)")
#x is catigorical
# Out:
# <Axes: xlabel='Review Rating', ylabel='Purchase Amount (USD)'>

# %%
# TODO: Create a boxplot that reveals the range of "Purchase Amount (USD)" for each "Promo Code Used" 
# Documentation: https://seaborn.pydata.org/generated/seaborn.boxplot.html

sns.boxplot(x=df["Promo Code Used"], y=df["Purchase Amount (USD)"])
# Out:
# <Axes: xlabel='Promo Code Used', ylabel='Purchase Amount (USD)'>

# %%
# TODO: Create a scatter-plot that reveals the relationship of "Age" & "Purchase Amount (USD)" 
# Documentation: https://seaborn.pydata.org/generated/seaborn.scatterplot.html

sns.scatterplot(data=df, x="Age", y="Purchase Amount (USD)", hue="Payment Method")
# Out:
# <Axes: xlabel='Age', ylabel='Purchase Amount (USD)'>

# %%
#two brakets returns it as a datframe 
#one braket returns a series from our dataframe
#df["Purchase Amount (USD)"]
df[["Purchase Amount (USD)"]]
# Out:
#       Purchase Amount (USD)
# 0                 30.904467
# 1                 31.588259
# 2                 24.231704
# 3                 33.918834
# 4                 36.545487
# ...                     ...
# 3895              61.610602
# 3896              44.600556
# 3897              41.781965
# 3898              45.343778
# 3899              49.439181
#
# [3900 rows x 1 columns]

# %%
# TODO: Cut your dataframe into two groups on "Purchase Amount (USD)" using the "cut" function
# Assign the labels of "low" to the first cut and "high" to the second cut
# in a new column called "Purchase Group"
# Documentation: https://pandas.pydata.org/docs/reference/api/pandas.cut.html 

#whats going on: this splits the purchase amnt column 
#Pandas will add a column if we name and add to data like we do here:
df["Purchase Group"] = pd.cut(df["Purchase Amount (USD)"], 2, labels =["low", "high"])

df
# Out:
#       Customer ID   Age  Gender Item Purchased  Purchase Amount (USD)  \
# 0            3475   NaN    Male         Jacket              30.904467
# 1            3698  21.0  Female       Backpack              31.588259
# 2            2756  31.0    Male       Leggings              24.231704
# 3            3340   NaN    Male        Pajamas              33.918834
# 4            3391  38.0    Male     Sunglasses              36.545487
# ...           ...   ...     ...            ...                    ...
# 3895          147  43.0  Female     Sunglasses              61.610602
# 3896         1472  37.0    Male        Pajamas              44.600556
# 3897         1069   NaN  Female        Handbag              41.781965
# 3898         1171  39.0    Male         Hoodie              45.343778
# 3899          478  21.0  Female         Gloves              49.439181
#
#           Location Size         Color  Season  Review Rating   Shipping Type  \
# 0            Maine    M  Burnt orange    Fall            4.0        Standard
# 1              NaN    L     Turquoise  Winter            2.0         Express
# 2           Nevada    M   Terra cotta  Winter            4.0        Standard
# 3         Nebraska    M         Black  Winter            NaN        Standard
# 4           Oregon    S     Aubergine  Summer            NaN        Standard
# ...            ...  ...           ...     ...            ...             ...
# 3895      Colorado    S  Burnt orange    Fall            NaN  2-Day Shipping
# 3896        Alaska    S     Aubergine  Winter            4.0  2-Day Shipping
# 3897       Wyoming    M       Fuchsia  Summer            NaN        Standard
# 3898      Illinois    S     Brick red    Fall            NaN  2-Day Shipping
# 3899  North Dakota    M     Aubergine  Winter            4.0  2-Day Shipping
#
#      Promo Code Used  Previous Purchases Payment Method  \
# 0                 No                   0    Credit Card
# 1                 No                   1    Credit Card
# 2                 No                   0    Credit Card
# 3                 No                   2    Credit Card
# 4                 No                   0    Credit Card
# ...              ...                 ...            ...
# 3895             Yes                   7          Venmo
# 3896             Yes                  20          Venmo
# 3897             Yes                  13          Venmo
# 3898             Yes                   3          Venmo
# 3899             Yes                   2          Venmo
#
#      Frequency of Purchases Purchase Group
# 0                       NaN            low
# 1                   Monthly            low
# 2                       NaN            low
# 3                 Bi-Weekly            low
# 4                       NaN            low
# ...                     ...            ...
# 3895                    NaN           high
# 3896                    NaN           high
# 3897                    NaN           high
# 3898                    NaN           high
# 3899                    NaN           high
#
# [3900 rows x 16 columns]

# %%
# TODO: Using this new "Purchase Group" column and boolean indexing create a 
# new dataframe of only rows where "Purchase Group" == "high", name this dataframe "high_group"

high_group = df[df["Purchase Group"] == "high"] 
high_group
# Out:
#       Customer ID   Age  Gender Item Purchased  Purchase Amount (USD)  \
# 42           1709  36.0  Female          Scarf              44.032444
# 67           3640  34.0  Female        Handbag              41.224453
# 74           2725  38.0  Female          Dress              43.453810
# 115          2326   NaN  Female          Dress              40.628163
# 147          2523  41.0  Female         Shorts              42.476011
# ...           ...   ...     ...            ...                    ...
# 3895          147  43.0  Female     Sunglasses              61.610602
# 3896         1472  37.0    Male        Pajamas              44.600556
# 3897         1069   NaN  Female        Handbag              41.781965
# 3898         1171  39.0    Male         Hoodie              45.343778
# 3899          478  21.0  Female         Gloves              49.439181
#
#            Location Size                 Color  Season  Review Rating  \
# 42          Florida    L  Muted mustard yellow  Winter            NaN
# 67         Illinois    M               Fuchsia  Summer            NaN
# 74         Missouri    M              Lavender  Summer            4.0
# 115        New York    M             Baby blue  Spring            4.0
# 147   Massachusetts    S          Lemon yellow  Summer            NaN
# ...             ...  ...                   ...     ...            ...
# 3895       Colorado    S          Burnt orange    Fall            NaN
# 3896         Alaska    S             Aubergine  Winter            4.0
# 3897        Wyoming    M               Fuchsia  Summer            NaN
# 3898       Illinois    S             Brick red    Fall            NaN
# 3899   North Dakota    M             Aubergine  Winter            4.0
#
#        Shipping Type Promo Code Used  Previous Purchases Payment Method  \
# 42          Standard              No                   2    Credit Card
# 67          Standard              No                   3    Credit Card
# 74          Standard              No                   5    Credit Card
# 115         Standard              No                   1    Credit Card
# 147         Standard              No                   0    Credit Card
# ...              ...             ...                 ...            ...
# 3895  2-Day Shipping             Yes                   7          Venmo
# 3896  2-Day Shipping             Yes                  20          Venmo
# 3897        Standard             Yes                  13          Venmo
# 3898  2-Day Shipping             Yes                   3          Venmo
# 3899  2-Day Shipping             Yes                   2          Venmo
#
#      Frequency of Purchases Purchase Group
# 42                Quarterly           high
# 67                Quarterly           high
# 74                  Monthly           high
# 115                Annually           high
# 147                     NaN           high
# ...                     ...            ...
# 3895                    NaN           high
# 3896                    NaN           high
# 3897                    NaN           high
# 3898                    NaN           high
# 3899                    NaN           high
#
# [1698 rows x 16 columns]

# %%
# TODO: Using the "value_counts" function, print out the count of each unique state
# in the "high_group" dataframe

high_group.value_counts("Location")
# Out:
# Location
# Indiana           44
# West Virginia     39
# Nevada            39
# Iowa              37
# Maryland          37
# Missouri          37
# California        37
# New York          36
# South Carolina    36
# Idaho             36
# Minnesota         36
# Oregon            36
# North Dakota      36
# Nebraska          35
# Arkansas          35
# Massachusetts     35
# Mississippi       34
# Wisconsin         34
# Kentucky          33
# Montana           32
# Louisiana         32
# New Mexico        32
# Illinois          32
# Delaware          32
# New Hampshire     32
# North Carolina    31
# Georgia           31
# Florida           31
# Washington        30
# Alabama           30
# Ohio              29
# Vermont           29
# Tennessee         29
# Pennsylvania      28
# Virginia          28
# Texas             28
# Utah              27
# Maine             27
# Colorado          27
# Hawaii            27
# Wyoming           26
# Michigan          25
# Oklahoma          25
# New Jersey        24
# South Dakota      24
# Alaska            23
# Rhode Island      21
# Connecticut       21
# Arizona           20
# Kansas            15
# Name: count, dtype: int64

# %% [markdown]
# ## Data Exploration Lab II
#
# In the next section, answer a few questions regarding your dataset using the visualizations you've generated.

# %% [markdown]
# ### Q1
#
# What is the most common payment method according to our bar-chart visualization? Which categories, if any, do you expect to be associated with differences in payment methods? (`Ex: Different seasons will have have different payment methods.`)

# %% [markdown]
# The most common payment method according to our bar-chart visualization are credit cards.
#
# The categories that I would expect to be associated with differences in payment methods might include purchase amount and age.
#
# Different purchase amount as well as age will have different payment methods.

# %% [markdown]
# ### Q2
#
# What is the most common color according to our bar-chart visualization? Which categories, if any, do you expect to be associated with differences in color? (`Ex: Different ages will have have different  methods.`)

# %% [markdown]
# According to our bar-chart visualization the most common color is black.
#
# Different seasons will have different common colors.

# %% [markdown]
# ### Q3
#
# Observing the box-plot of "Review Rating" vs "Purchase Amount (USD)", which trends in median do you notice across reviews, if any?

# %% [markdown]
# The observable trend from the box-plot of "Review Rating" vs "Purchase Amount (USD)" shows that higher medians tend to be associated with higher ratings.

# %% [markdown]
# ### Q4
#
# Observing the scatter-plot of "Age" & "Purchase Amount (USD)", which trends do you notice across age, if any?

# %% [markdown]
# There is no significant trend from the scatter-plot of "Age" & "Purchase Amount (USD)", there is too much noise in our graph.

# %% [markdown]
# ### Q5
#
# What does this scatter-plot tell you about age and purchasing habits?

# %% [markdown]
# The scatter-plot tells us that older ages tend to have lower purchasing habits. They also use things such as cash and wire transfers more often than younger age shoppers.
